# %%
import os
os. getcwd()
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
import os
os. getcwd()
# Out:
# 'C:\\Users\\abc\\sundram sir'

# %% [markdown]
# EDA
# Number Of Terrorist Activities Each Year                              :-Barplot & Countplot
# Total attacks in each region                                          :-Barplot & Countplot
# Attacking Methods by Terrorists                                       :-Countplot
# Terrorist Attack type                                                 :-Pie chart
# Favrourite Target type                                                :-Pei chart & Countplot
# Terrorist Groups with Highest Terror Attacks                          :-Barplot
# Number of kills by each terrorist group in each country Visualization :-
# Highest casualities from each terrorist attackes                      :- Barplot
# Most Affected Country                                                 :-Barplot and Countplot
# Most Affected City                                                    :-Barplot & Countplot
# TOP10 Terrorist Group Attacks
# Terror attack in india:most affected year,city

# %% [markdown]
# # Reading csv file

# %%
dataset=pd.read_csv("globalterrorism_raghavdata.csv",encoding="latin-1") #encoding = 'ISO-8859-1')

# %% [markdown]
# # Analysing data

# %%
dataset.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
dataset.shape
# Out:
# (181691, 135)

# %%
#check whole data
pd.set_option('display.max_columns',None)
dataset.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
#check all columns name
print(dataset.columns.tolist())
# Out:
# ['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended', 'resolution', 'country', 'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'multiple', 'success', 'suicide', 'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'cla
# ...

# %% [markdown]
# # Rename coulmns name

# %%
dataset.rename(columns={'iyear':'Year','imonth':'Month','iday':"day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'latitude',
    'longitude':'longitude','summary':'summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'kill',
     'nwound':'Wound'},inplace=True)

# %%
dataset = dataset[['Year','Month','day','Country','State','Region','City','latitude','longitude',"Attacktype",'kill',
               'Wound','target1','summary','Group','Targettype','Weapon','motive']]

# %%
dataset.head()
# Out:
#    Year  Month  day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   latitude   longitude                      Attacktype  kill  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Unknown  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   NaN
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   NaN
#
# ...

# %%
df=dataset

# %%
df.shape
# Out:
# (181691, 18)

# %%
df.isnull().sum()
# Out:
# Year               0
# Month              0
# day                0
# Country            0
# State            421
# Region             0
# City             434
# latitude        4556
# longitude       4557
# Attacktype         0
# kill           10313
# Wound          16311
# target1          636
# summary        66129
# Group              0
# Targettype         0
# Weapon             0
# motive        131130
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 18 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Year        181691 non-null  int64
#  1   Month       181691 non-null  int64
#  2   day         181691 non-null  int64
#  3   Country     181691 non-null  object
#  4   State       181270 non-null  object
#  5   Region      181691 non-null  object
#  6   City        181257 non-null  object
#  7   latitude    177135 non-null  float64
#  8   longitude   177134 non-null  float64
#  9   Attacktype  181691 non-null  object
#  10  kill        171378 non-null  float64
#  11  Wound       165380 non-null  float64
#  12  target1     181055 non-null  object
#  13  summary     115562 non-null  object
#  14  Group       181691 non-null  object
#  15  Targettype  181691 non-null  object
#  16  Weapon      181691 non-null  object
#  17  motive      50561 non-null   object
# ...

# %%
EE=pd.DataFrame(df['Year'].value_counts())
EE
# Out:
#        Year
# 2014  16903
# 2015  14965
# 2016  13587
# 2013  12036
# 2017  10900
# 2012   8522
# 2011   5076
# 1992   5071
# 2010   4826
# 2008   4805
# 2009   4721
# 1991   4683
# 1989   4324
# 1990   3887
# 1988   3721
# 1984   3495
# 1994   3456
# 2007   3242
# 1997   3197
# 1987   3183
# 1995   3081
# 1996   3058
# 1985   2915
# 1983   2870
# 1986   2860
# 2006   2758
# 1979   2662
# 1980   2662
# 1981   2586
# 1982   2544
# 2005   2017
# 2001   1906
# 2000   1814
# 1978   1526
# 1999   1395
# 2002   1333
# 1977   1319
# 2003   1278
# 2004   1166
# 1998    934
# 1976    923
# 1975    740
# 1970    651
# 1974    581
# 1972    568
# 1973    473
# 1971    471

# %%
df["Wound"]=df["Wound"].fillna(0)
df["kill"]=df["kill"].fillna(0)

# %%
df.isnull().sum()
# Out:
# Year               0
# Month              0
# day                0
# Country            0
# State            421
# Region             0
# City             434
# latitude        4556
# longitude       4557
# Attacktype         0
# kill               0
# Wound              0
# target1          636
# summary        66129
# Group              0
# Targettype         0
# Weapon             0
# motive        131130
# dtype: int64

# %%
df["casualities"]=df["kill"]+df["Wound"]

# %%
df.head()
# Out:
#    Year  Month  day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   latitude   longitude                      Attacktype  kill  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Unknown  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   0.0
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   0.0
#
# ...

# %%
df.describe()
# Out:
#                 Year          Month            day       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           longitude           kill          Wound    casualities
# count  1.771340e+05  181691.000000  181691.000000  181691.000000
# mean  -4.586957e+02       2.266860       2.883296       5.150156
# std    2.047790e+05      11.227057      34.309747      40.555416
# min   -8.618590e+07       0.000000       0.000000       0.000000
# ...

# %%
df.Weapon.value_counts()
# Out:
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# ...

# %% [markdown]
# # Number of Total Attacks in Each Years

# %%
df["Year"].value_counts()
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# 1984     3495
# 1994     3456
# 2007     3242
# 1997     3197
# 1987     3183
# 1995     3081
# 1996     3058
# 1985     2915
# 1983     2870
# 1986     2860
# 2006     2758
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 2005     2017
# 2001     1906
# 2000     1814
# 1978     1526
# 1999     1395
# 2002     1333
# 1977     1319
# 2003     1278
# 2004     1166
# 1998      934
# 1976      923
# 1975      740
# 1970      651
# 1974      581
# 1972      568
# 1973      473
# 1971      471
# Name: Year, dtype: int64

# %%
plt.subplots(figsize=(15,6))
sns.barplot(df['Year'].value_counts().index, df['Year'].value_counts().values)
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities Each Year')
plt.show()

# %%
year = df['Year'].unique()
years_count = df['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = year,
           y = years_count,
           palette = "tab10")
plt.xticks(rotation = 50)
plt.xlabel('Attacking Year',fontsize=20)
plt.ylabel('Number of Attacks Each Year',fontsize=20)
plt.title('Attacks In Years',fontsize=30)
plt.show()

# %%
plt.subplots(figsize=(15,6))
sns.countplot('Year',data=df,palette=None,edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities Each Year')
plt.show()

# %% [markdown]
# # Total Terrorist Attacks in Region

# %%
plt.figure(figsize=(23,16),dpi=100)
ax=sns.countplot(x='Region',data=df)
plt.xlabel=("Total Terrorist Activities in Region")
plt.ylabel=("Total Number of attckes")
for i in ax.containers:
    ax.bar_label(i)

# %%
plt.subplots(figsize=(15,6))
sns.barplot(df['Region'].value_counts().index, df['Region'].value_counts().values)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Attacking Methods by Terrorists

# %%
plt.subplots(figsize=(15,6))
sns.countplot('Attacktype',data=df, palette=None,order=df['Attacktype'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Attacking Methods by Terrorists')
plt.show()

# %% [markdown]
# # Terrorist Attack type

# %%
df["Attacktype"].value_counts()
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attacktype, dtype: int64

# %%
plt.figure(figsize=(15,12),dpi=250)
plt.pie(df.Attacktype.value_counts().drop("Unknown"),labels=df.Attacktype.value_counts().drop("Unknown").index,autopct='%.2f%%',explode=[0.02 for i in range(8)])

plt.show()

# %% [markdown]
# # Favourite Target Type

# %%
Targett = df['Targettype'].value_counts()
Targett['Others'] = Targett[Targett[:] <= 1000].sum()
Targett.drop(Targett[Targett[:] <= 1000].index, inplace=True)
Targett
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# Others                             2478
# Name: Targettype, dtype: int64

# %%
plt.figure(figsize=(16,22))
plt.pie(Targett.tolist(), labels=Targett.index.tolist(), autopct='%1.1f%%',shadow=True, startangle=0)
plt.title('Distribution according to Target Type\n', weight='bold')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.countplot(df['Targettype'],palette='rainbow_r',order=df['Targettype'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Favorite Targets', weight='bold')
plt.show()

# %% [markdown]
# # Terrorist Groups with Highest Terror Attacks

# %%
TGroup=df['Group'].value_counts()

# %%
plt.subplots(figsize=(15,9))
sns.barplot(TGroup[1:21].values, TGroup[1:21].index)
plt.xticks(rotation=90)
plt.title('Terrorist Groups with Highest Terror Attacks')
plt.show()

# %%
df['Group'].value_counts().drop('Unknown').head(10).plot(kind='bar',color='green',figsize=(20,10))
plt.title("Top 10 terrorist group attack",fontsize=20)
plt.show()

# %% [markdown]
# # number of kills by each terrorist group in each country Visualization

# %%
ndf=df[['Group','Country','casualities']]
ndf=ndf.groupby(['Group','Country'],axis=0).sum().sort_values('casualities',ascending=False).drop('Unknown').reset_index().head(10)
ndf
# Out:
#                                               Group        Country  \
# 0                                           Taliban    Afghanistan
# 1       Islamic State of Iraq and the Levant (ISIL)           Iraq
# 2                                        Boko Haram        Nigeria
# 3           Liberation Tigers of Tamil Eelam (LTTE)      Sri Lanka
# 4                                          Al-Qaida  United States
# 5                   Tehrik-i-Taliban Pakistan (TTP)       Pakistan
# 6                                 Shining Path (SL)           Peru
# 7                                  Al-Qaida in Iraq           Iraq
# 8                                        Al-Shabaab        Somalia
# 9  Farabundo Marti National Liberation Front (FMLN)    El Salvador
#
#    casualities
# 0      57140.0
# 1      54755.0
# 2      24588.0
# 3      21919.0
# 4      19494.0
# 5      15532.0
# 6      14625.0
# 7      14348.0
# 8      14201.0
# 9      12068.0

# %%
# number of kills by each terrorist group in each country Visualization
ndf=df[['Group','Country','casualities',"kill","Wound"]]
ndf=ndf.groupby(['Group','Country'],axis=0).sum().sort_values('casualities',ascending=False).drop('Unknown').reset_index().head(10)
ndf
# Out:
#                                               Group        Country  \
# 0                                           Taliban    Afghanistan
# 1       Islamic State of Iraq and the Levant (ISIL)           Iraq
# 2                                        Boko Haram        Nigeria
# 3           Liberation Tigers of Tamil Eelam (LTTE)      Sri Lanka
# 4                                          Al-Qaida  United States
# 5                   Tehrik-i-Taliban Pakistan (TTP)       Pakistan
# 6                                 Shining Path (SL)           Peru
# 7                                  Al-Qaida in Iraq           Iraq
# 8                                        Al-Shabaab        Somalia
# 9  Farabundo Marti National Liberation Front (FMLN)    El Salvador
#
#    casualities     kill    Wound
# 0      57140.0  29269.0  27871.0
# 1      54755.0  31058.0  23697.0
# 2      24588.0  16917.0   7671.0
# 3      21919.0  10928.0  10991.0
# 4      19494.0   3001.0  16493.0
# ...

# %%
plt.figure(figsize=(20,6),dpi=100)
ax=sns.barplot(x='Country',y='casualities',data=ndf,ci=False)
for i in ax.containers:
    ax.bar_label(i,fmt='%.2f')
    
plt.show()

# %% [markdown]
# # Highest casualitities from each  type of attack

# %%
df["Attacktype"].value_counts()
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attacktype, dtype: int64

# %%
plt.figure(figsize=(20,6),dpi=100)
ax=sns.barplot(x='Attacktype',y='casualities',data=df,ci=False)
for i in ax.containers:
    ax.bar_label(i,fmt='%.2f')
    
plt.show()

# %% [markdown]
# # Most affected Country

# %%
#country affect

plt.subplots(figsize=(20,10))
sns.barplot(df['Country'].value_counts()[:10].index,df['Country'].value_counts()[:10].values,palette='YlOrBr_r')
plt.title('Top Countries Affected')
plt.xticks(rotation = 50)
plt.show()

# %%
plt.subplots(figsize=(13,45))
sns.countplot(y='Country',data=df)
plt.title('Number of attacks per country')
plt.show()

# %% [markdown]
# # Most Affected city

# %%
df['City'].value_counts().drop("Unknown").to_frame().sort_values('City',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(20,10),color='red')
plt.xticks(rotation = 50)

plt.title("Top 10 most effected city",fontsize=20)
plt.show()

# %% [markdown]
# # TOP10 Terrorist Group Attacks

# %%
# number of kills by each terrorist group in each country Visualization
ddf=df[['Group','Country','casualities',"City","Year","Attacktype"]]
ddf=ddf.groupby(['Group','Country',"City","Year","Attacktype"],axis=0).sum().sort_values('casualities',ascending=False).drop('Unknown').reset_index().head(10)
ddf
# Out:
#                                          Group        Country           City  \
# 0                                     Al-Qaida  United States  New York City
# 1                               Aum Shinri Kyo          Japan          Tokyo
# 2                                     Al-Qaida          Kenya        Nairobi
# 3  Islamic State of Iraq and the Levant (ISIL)           Iraq        Baghdad
# 4  Islamic State of Iraq and the Levant (ISIL)           Iraq        Baghdad
# 5  Islamic State of Iraq and the Levant (ISIL)           Iraq        Baghdad
# 6                  Islamic State of Iraq (ISI)           Iraq        Baghdad
# 7  Islamic State of Iraq and the Levant (ISIL)           Iraq        Baghdad
# 8                                     Al-Qaida          Spain         Madrid
# 9  Islamic State of Iraq and the Levant (ISIL)           Iraq          Mosul
#
#    Year         Attacktype  casualities
# 0  2001          Hijacking      19148.0
# 1  1995    Unarmed Assault       5513.0
# ...

# %% [markdown]
# # Terror attack in India

# %%
terror_india = df[(df.Country == 'India')]
terror_india.head()
# Out:
#       Year  Month  day Country        State      Region        City  \
# 1186  1972      2   22   India        Delhi  South Asia   New Delhi
# 2764  1975      1    2   India        Bihar  South Asia  Samastipur
# 3857  1976      5   26   India        Delhi  South Asia   New Delhi
# 5327  1977      9   28   India  Maharashtra  South Asia      Bombay
# 7337  1979      1   13   India        Assam  South Asia     Unknown
#
#        latitude  longitude         Attacktype  kill  Wound  \
# 1186  28.585836  77.153336          Hijacking   0.0    0.0
# 2764  25.863042  85.781004  Bombing/Explosion   4.0    0.0
# 3857  28.585836  77.153336  Bombing/Explosion   0.0    0.0
# 5327  19.075984  72.877656          Hijacking   0.0    0.0
# 7337  26.200605  92.937574      Armed Assault   0.0    0.0
#
#                                     target1  \
# 1186                                  B-747
# 2764  Lalit Narayan Mishra and a legislator
# 3857                      New Delhi airport
# ...

# %%
terror_india['City'].value_counts().drop("Unknown").to_frame().sort_values('City',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(20,10),color='red')
plt.xticks(rotation = 50)

plt.title("Top 10 most effected city",fontsize=20)
plt.show()

# %%
plt.subplots(figsize=(15,6))
sns.countplot('Year',data=terror_india,palette=None,edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities Each Year')
plt.show()

# %%
print('Country with most attacks: ',df['Country'].value_counts().idxmax())
print('City with most attacks: ',df['City'].value_counts().index[1])
print("Region with the most attacks:",df['Region'].value_counts().idxmax())
print("Year with the most attacks:",df['Year'].value_counts().idxmax())
print("Group with the most attacks:",df['Group'].value_counts().index[1])
print("Most Attack Types:",df['Attacktype'].value_counts().idxmax())
# Out:
# Country with most attacks:  Iraq
# City with most attacks:  Baghdad
# Region with the most attacks: Middle East & North Africa
# Year with the most attacks: 2014
# Group with the most attacks: Taliban
# Most Attack Types: Bombing/Explosion
